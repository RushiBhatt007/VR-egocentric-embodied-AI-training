# %%
import pybullet
import time
import pybullet_data
import pybullet_robots
import math
import numpy as np
import threading
import matplotlib.pyplot as plt
import cv2
import os
import csv
# %matplotlib inline

# %%
#setup constants

#width and height for rgb and depth image
IMG_WIDTH = 160
IMG_HEIGHT = 120

#robot constants
NUM_JOINTS = 7
FINGER_AXES = [9, 10]

#task 
# 1 = push
# 2 = reach
# 3 = cube pick up and drop
task = 3

#data record path
# DATA_PATH = "data_all_cams_task_"+str(task)+"_ron"
DATA_PATH = "data_all_cam_task_1406"

# %%
#setup global variables
runNumber = 0 #folder number to save data

# %%
usingVR = True

#setup the simulation
if usingVR:
    physics = pybullet.connect(pybullet.SHARED_MEMORY)
    if (physics<0):
        print('could not use vr!')
    else:
        print('using vr')
else:
    physics = pybullet.connect(pybullet.GUI)

#add a plane to the simulation
pybullet.setAdditionalSearchPath(pybullet_data.getDataPath())
print(pybullet_data.getDataPath())
# Out:
# using vr
# c:\Users\Ronak\anaconda3\envs\torch\lib\site-packages\pybullet_data

# %%
# Task 1
def setupPushTask():
    # clear all the objects in the simulation
    pybullet.resetSimulation()
    plainId = pybullet.loadURDF("plane.urdf", [0, 0, 0], useFixedBase=True)

    # #add a table in front of the robot arm
    tableId = pybullet.loadURDF("table/table.urdf", basePosition=[0,0,0])

    #add misc objects to the simulation on the table
    pybullet.loadURDF("lego/lego.urdf", basePosition=[-0.37,0.1,0.7], globalScaling=2)

    # pybullet.loadURDF("tray/traybox.urdf", basePosition=[0.1, -0.3, 0.65], globalScaling=0.5)

    # Define the start and end region positions
    start_region = [-0.37, -0.3, 0.63]
    start_width = 0.15
    start_color = [1,0,0]
    start_lineWidth = 500


    # end_region = [-0.35, 0.2, 0.63]
    # end_width = 0.1
    # end_color = [0,0,1]
    # end_lineWidth = 500

    # Create rectangular regions to highlight the start and end regions
    start_region_lines = [
        pybullet.addUserDebugLine([start_region[0] - start_width, start_region[1] - start_width, start_region[2]],
                                 [start_region[0] + start_width, start_region[1] - start_width, start_region[2]],
                                 lineColorRGB=start_color, lineWidth=start_lineWidth),
        pybullet.addUserDebugLine([start_region[0] + start_width, start_region[1] - start_width, start_region[2]],
                                 [start_region[0] + start_width, start_region[1] + start_width, start_region[2]],
                                 lineColorRGB=start_color, lineWidth=start_lineWidth),
        pybullet.addUserDebugLine([start_region[0] + start_width, start_region[1] + start_width, start_region[2]],
                                 [start_region[0] - start_width, start_region[1] + start_width, start_region[2]],
                                 lineColorRGB=start_color, lineWidth=start_lineWidth),
        pybullet.addUserDebugLine([start_region[0] - start_width, start_region[1] + start_width, start_region[2]],
                                 [start_region[0] - start_width, start_region[1] - start_width, start_region[2]],
                                 lineColorRGB=start_color, lineWidth=start_lineWidth)
    ]

    # end_region_lines = [
    # pybullet.addUserDebugLine([end_region[0] - end_width, end_region[1] - end_width, end_region[2]],
    #                          [end_region[0] + end_width, end_region[1] - end_width, end_region[2]],
    #                          lineColorRGB=end_color, lineWidth=end_lineWidth),
    # pybullet.addUserDebugLine([end_region[0] + end_width, end_region[1] - end_width, end_region[2]],
    #                          [end_region[0] + end_width, end_region[1] + end_width, end_region[2]],
    #                          lineColorRGB=end_color, lineWidth=end_lineWidth),
    # pybullet.addUserDebugLine([end_region[0] + end_width, end_region[1] + end_width, end_region[2]],
    #                          [end_region[0] - end_width, end_region[1] + end_width, end_region[2]],
    #                          lineColorRGB=end_color, lineWidth=end_lineWidth),
    # pybullet.addUserDebugLine([end_region[0] - end_width, end_region[1] + end_width, end_region[2]],
    #                          [end_region[0] - end_width, end_region[1] - end_width, end_region[2]],
    #                          lineColorRGB=end_color, lineWidth=end_lineWidth)
# ]


    #add a robot arm to the simulation
    robotId = pybullet.loadURDF("franka_panda/panda.urdf", [-0,0.3,0.6], useFixedBase=True)
    #set the arm to an experimentally good starting position
    initState = [1.412535051938124, 1.6189544050236317, 0.9125956760870967, -2.606972451796825, -0.648868805466964, 2.6805359081158495, 5.485746666193374]

    for i in range(len(initState)):
        pybullet.resetJointState(robotId, i, initState[i])

    #set the gravity
    pybullet.setGravity(0, 0, -10)

    # create a thread to run the simulation
    pybullet.setRealTimeSimulation(1)
    
    return robotId

# Task 2
def setupReachTask():
    # clear all the objects in the simulation
    pybullet.resetSimulation()
    plainId = pybullet.loadURDF("plane.urdf", [0, 0, 0], useFixedBase=True)

    # #add a table in front of the robot arm
    tableId = pybullet.loadURDF("table/table.urdf", basePosition=[0,0,0])

    #add misc objects to the simulation on the table
    pybullet.loadURDF("lego/lego.urdf", basePosition=[-0.6,-0.2,0.7], globalScaling=2)

    #add a robot arm to the simulation
    robotId = pybullet.loadURDF("franka_panda/panda.urdf", [-0,0.3,0.6], useFixedBase=True)
    # robotId = pybullet.loadURDF("kuka_iiwa/model.urdf", [-0,0.3,0.6], useFixedBase=True)
    #set the arm to an experimentally good starting position
    initState = [1.976510182790837, -1.4559139655311553, 1.2882844021675286, -1.572705259702399, 1.3237965931867992, 1.110313401859266, 2.873038394359566]

    for i in range(len(initState)):
        pybullet.resetJointState(robotId, i, initState[i])

    #set the gravity
    pybullet.setGravity(0, 0, -10)

    # create a thread to run the simulation
    pybullet.setRealTimeSimulation(1)
    
    return robotId

# Task 3
def setupCubeTask():
    # clear all the objects in the simulation
    pybullet.resetSimulation()
    plainId = pybullet.loadURDF("plane.urdf", [0, 0, 0], useFixedBase=True)

    # #add a table in front of the robot arm
    tableId = pybullet.loadURDF("table/table.urdf", basePosition=[0,0,0])

    #add misc objects to the simulation on the table
    pybullet.loadURDF("lego/lego.urdf", basePosition=[-0.6,-0.2,0.7], globalScaling=2)

    pybullet.loadURDF("tray/traybox.urdf", basePosition=[0.0, -0.3, 0.65], globalScaling=0.5)

    #add a robot arm to the simulation
    robotId = pybullet.loadURDF("franka_panda/panda.urdf", [-0,0.3,0.6], useFixedBase=True)
    # robotId = pybullet.loadURDF("kuka_iiwa/model.urdf", [-0,0.3,0.6], useFixedBase=True)
    #set the arm to an experimentally good starting position
    initState = [1.976510182790837, -1.4559139655311553, 1.2882844021675286, -1.572705259702399, 1.3237965931867992, 1.110313401859266, 2.873038394359566]

    for i in range(len(initState)):
        pybullet.resetJointState(robotId, i, initState[i])

    #set the gravity
    pybullet.setGravity(0, 0, -10)

    # create a thread to run the simulation
    pybullet.setRealTimeSimulation(1)
    
    return robotId

# %%
def getRandomPos(x_range = [-0.6, -0.2], y_range = [-0.2, 0]):
        x = np.random.uniform(x_range[0], x_range[1])
        y = np.random.uniform(y_range[0], y_range[1])
        return [x, y, 0.7]

def reset():
     if task == 1:
            return setupPushTask()
     elif task == 2:
            return setupReachTask()
     elif task == 3:
            return setupCubeTask()
     
robotId = reset()

# %%
# for i in range(0,7):
#     pos = pybullet.getJointState(robotId, i)[0]
#     # pos, orientation = pybullet.getLinkState(robotId, i, computeForwardKinematics=False)[0:2]
#     print(pos)

# %%
#Helper functions for controlling the robot arm
isGrabberOpen = False
def openGrabber():
    global isGrabberOpen
    for i in FINGER_AXES:
        pybullet.setJointMotorControl2(robotId, i, pybullet.POSITION_CONTROL, targetPosition=0.04, force=100)
    isGrabberOpen = True

def closeGrabber():
    global isGrabberOpen
    for i in FINGER_AXES:
        pybullet.setJointMotorControl2(robotId, i, pybullet.POSITION_CONTROL, targetPosition=0, force=100)
    isGrabberOpen = False

def setEndEffectorPos(pos, orientation):
    #first get desired joint positions via inverse kinematics
    jointPoses = pybullet.calculateInverseKinematics(robotId, 8, pos, orientation)
    for i in range(len(jointPoses)):
        if i in FINGER_AXES:
            continue
            
        pybullet.setJointMotorControl2(robotId, i, pybullet.POSITION_CONTROL, targetPosition=jointPoses[i], force=100)

# %%
#reset()
def getIsOpen():
    global isGrabberOpen
    return isGrabberOpen

def getPointsOnEndEffector(visualize=False):
    linkNum = 8
    #cet center position
    endEffectorPos, endEffectorOrn = pybullet.getLinkState(robotId, linkNum)[:2]
    #use orientation to compute the other two points
    rotMat = pybullet.getMatrixFromQuaternion(endEffectorOrn)
    rotMat = np.array(rotMat).reshape(3,3)
    localPos = np.array([0, 0.2, 0])
    endEffectorPos2 = endEffectorPos + rotMat.dot(localPos)
    localPos = np.array([0.2, 0, 0])
    endEffectorPos3 = endEffectorPos + rotMat.dot(localPos)

    endState = np.array(endEffectorPos)
    endState = np.append(endState, pybullet.getEulerFromQuaternion(endEffectorOrn))

    if visualize:
        #add small spheres to visualize the points
        pybullet.addUserDebugLine(endEffectorPos, endEffectorPos2, [1,0,0], 1, 0.1)
        pybullet.addUserDebugLine(endEffectorPos, endEffectorPos3, [0,1,0], 1, 0.1)
    
    return [endEffectorPos, endEffectorPos2, endEffectorPos3], endState

def getImagesFromPOV(matrixParameters):
    viewMatrix = pybullet.computeViewMatrixFromYawPitchRoll(cameraTargetPosition=matrixParameters['cameraTargetPosition'], distance=matrixParameters['distance'], yaw=matrixParameters['yaw'], pitch=matrixParameters['pitch'], roll=matrixParameters['roll'], upAxisIndex=matrixParameters['upAxisIndex'])
    projectionMatrix = pybullet.computeProjectionMatrixFOV(fov=60, aspect=float(IMG_WIDTH)/IMG_HEIGHT, nearVal=0.1, farVal=100.0)
    image = pybullet.getCameraImage(IMG_WIDTH, IMG_HEIGHT, viewMatrix=viewMatrix, projectionMatrix=projectionMatrix, shadow=1, lightDirection=[1,1,1], lightColor=[1,1,1], lightDistance=1, lightAmbientCoeff=0.5, lightDiffuseCoeff=0.5, lightSpecularCoeff=0.5, renderer=pybullet.ER_BULLET_HARDWARE_OPENGL, flags=pybullet.ER_NO_SEGMENTATION_MASK)

    #show the image in frame
    width = image[0]
    height = image[1]
    rgb = image[2]
    depth = image[3]
    segmentation = image[4]

    #convert to numpy array
    rgb = np.reshape(rgb, (height, width, 4))
    rgb = rgb[:, :, :3] #remove alpha channel
    
    depth = np.reshape(depth, (height, width))
    return rgb, depth


def getTrainingData():
    '''return everything in a timestep needed for training (rgb img, depth mask, end effector pos, finger open)
    '''

    #get the 3 points on the end effector
    endEffectorPoints, endState = getPointsOnEndEffector()

    #get if the grabber is open
    isOpen = getIsOpen()

    topMatrixParameters = {'cameraTargetPosition':[0,0,0.5],
                           'distance':1.2,
                           'yaw':0,
                           'pitch':-45,
                           'roll':0,
                           'upAxisIndex':2}

    rgb_top, depth_top = getImagesFromPOV(topMatrixParameters)

    newEndEffectorPosition = [endEffectorPoints[0][0]-0.0, endEffectorPoints[0][1]+0.0, endEffectorPoints[0][2]-0]
    effMatrixParameters = {'cameraTargetPosition':newEndEffectorPosition,
                           'distance':-0.06,
                           'yaw':0,
                           'pitch':90,
                           'roll':0,
                           'upAxisIndex':2}

    rgb_eff, depth_eff = getImagesFromPOV(effMatrixParameters)

    sideMatrixParameters = {'cameraTargetPosition':[0,-0.5,1],
                           'distance':0.6,
                           'yaw':0,
                           'pitch':0,
                           'roll':0,
                           'upAxisIndex':2}

    rgb_side, depth_side = getImagesFromPOV(sideMatrixParameters)
    
    return rgb_top, depth_top, rgb_eff, depth_eff,rgb_side, depth_side, endEffectorPoints, endState, isOpen

#visualize sample image
rgb_top, depth_top, rgb_eff, depth_eff,rgb_side, depth_side, endEffectorPoints, endState, isOpen = getTrainingData()
plt.imshow(rgb_top)
plt.show()
plt.imshow(depth_top)
plt.show()
plt.imshow(rgb_eff)
plt.show()
plt.imshow(depth_eff)
plt.show()
plt.imshow(rgb_side)
plt.show()
plt.imshow(depth_side)
plt.show()

# %%
isCollectingImgs = False

def saveRGBDepth(rgbImgs, depthImgs, rgbPath, depthPath):
    for i in range(len(rgbImgs)):
        #convert to bgr for opencv
        bgr = rgbImgs[i][:, :, ::-1]
        cv2.imwrite(f"{rgbPath}/rgb{i}.png", bgr)
    
    for i in range(len(depthImgs)):
        #convert to int
        img = (depthImgs[i] * 255).astype(np.uint8)
        cv2.imwrite(f"{depthPath}/depth{i}.png", img)

def continuousRecordImgs10Hz():
    global runNumber
    rgbTopImgs = []
    depthTopImgs = []
    rgbEffImgs = []
    depthEffImgs = []
    rgbSideImgs = []
    depthSideImgs = []
    points = []
    opens = []
    endStates = []
    while isCollectingImgs:
        startTime = time.time()
        rgb_top, depth_top, rgb_eff, depth_eff,rgb_side, depth_side, endEffectorPoints, endState, isOpen = getTrainingData()

        # Saving all images
        rgbTopImgs.append(rgb_top)
        depthTopImgs.append(depth_top)
        rgbEffImgs.append(rgb_eff)
        depthEffImgs.append(depth_eff)
        rgbSideImgs.append(rgb_side)
        depthSideImgs.append(depth_side)
        
        points.append(endEffectorPoints)
        endStates.append(endState)
        opens.append(isOpen)

        endTime = time.time()
        sleepTime = 0.1 - (endTime - startTime)
        if sleepTime > 0:
            time.sleep(sleepTime)
        else:
            print("Warning: Data collection is too slow, took", endTime - startTime, "seconds to collect one image")
    
    #save the images
    dataPath = f"{DATA_PATH}/{runNumber}"
    os.mkdir(dataPath)    
    rgbPathTop = f"{dataPath}/rgb_Top"
    depthPathTop = f"{dataPath}/depth_Top"
    os.mkdir(rgbPathTop)
    os.mkdir(depthPathTop)
    rgbPathEff = f"{dataPath}/rgb_Eff"
    depthPathEff = f"{dataPath}/depth_Eff"
    os.mkdir(rgbPathEff)
    os.mkdir(depthPathEff)
    rgbPathSide = f"{dataPath}/rgb_Side"
    depthPathSide = f"{dataPath}/depth_Side"
    os.mkdir(rgbPathSide)
    os.mkdir(depthPathSide)

    statePath = f"{dataPath}/states"
    os.mkdir(statePath)

    saveRGBDepth(rgbTopImgs, depthTopImgs, rgbPathTop, depthPathTop)
    saveRGBDepth(rgbEffImgs, depthEffImgs, rgbPathEff, depthPathEff)
    saveRGBDepth(rgbSideImgs, depthSideImgs, rgbPathSide, depthPathSide)

    #create a csv file with the points and opens for each time step
    for i in range(len(points)):
        with open(f"{statePath}/states{i}.csv", "w") as f:
            f.write(f'{points[i][0][0]},{points[i][0][1]}')
            f.write(f',{points[i][1][0]},{points[i][1][1]}')
            f.write(f',{points[i][2][0]},{points[i][2][1]}')
            if opens[i]:
                f.write(",1")
            else:
                f.write(",0")
            f.write('\n')
            f.write(f'{endStates[i][0]},{endStates[i][1]},{endStates[i][2]},{endStates[i][3]},{endStates[i][4]},{endStates[i][5]}')      

def stopRun():
    global runNumber
    global isCollectingImgs

    #stop data collection for this run
    isCollectingImgs = False
    time.sleep(0.2) #wait for the thread to stop

def startNextRun():
    global runNumber
    global isCollectingImgs
    #start the next run
    runNumber += 1
    isCollectingImgs = True
    thread = threading.Thread(target=continuousRecordImgs10Hz)
    thread.start()

# %%
# # RUSHI CODE

# isRunning = True

# # pybullet.setVRCameraState(trackObject=robotId)
# def updateControllerContinuously():
#     global robotId
    
#     # Button A -> controllerState[6][7]
#     # Button B -> controllerState[6][1]
#     # Front trigger -> controllerState[6][33]
#     # Side trigger -> controllerState[6][34] or controllerState[6][2]

#     # For starting recording use A and Front trigger together
#     # For stopping recording use B and Front trigger together

#     is_recording = 0
#     startRecord = False

#     while isRunning:
#         #get the position and orientation of the controller
#         controllerState = pybullet.getVREvents()
        
#         if len(controllerState)!=2:
#             continue
        
#         #For right controller, use 2nd set
#         controllerState = controllerState[1]

#         if controllerState[6][1]!=0 and controllerState[6][33]!=0:
#             stopRun()
#             print('Recording stopped...')
#             time.sleep(5) #stop mid-reset pictures from being recorded
#             # robotId = reset()
#             # time.sleep(5)
#             startRecord = False

#         elif (controllerState[6][7]!=0 and controllerState[6][33]!=0) or startRecord:
#             startRecord = True
#             #if trigger is pressed, close the grabber
#             if controllerState[6][33] == 1:
#                 closeGrabber()
#             else:
#                 openGrabber()

#             pos = controllerState[1]
#             orientation = controllerState[2]

#             #rotate orientation by 90 degrees in the x axis
#             orientation = pybullet.getEulerFromQuaternion(orientation)
#             orientation = list(orientation)
#             orientation[0] += math.pi
#             orientation = pybullet.getQuaternionFromEuler(orientation)
            
#             setEndEffectorPos(pos, orientation)

#             #convert to tuple
#             orientation = list(orientation)
        
#             time.sleep(3)
#             startNextRun()
#             is_recording = 1
#             print('Recording initiated...')
        
        

# #start the controller thread
# thread = threading.Thread(target=updateControllerContinuously)
# thread.start()

# %%
isRunning = True
# pybullet.setVRCameraState(trackObject=robotId)
def updateControllerContinuously():
    global robotId
    
    # Button A -> controllerState[6][7]
    # Button B -> controllerState[6][1]
    # Front trigger -> controllerState[6][33]
    # Side trigger -> controllerState[6][34] or controllerState[6][2]

    # For starting recording use A and Front trigger together
    # For stopping recording use B and Front trigger together

    is_recording = 0

    while isRunning:

        #get the position and orientation of the controller
        controllerState = pybullet.getVREvents()
        
        if len(controllerState)!=2:
            continue
        
        #For right controller, use 2nd set
        controllerState = controllerState[1]
        
        #if trigger is pressed, close the grabber
        if controllerState[6][33] == 1:
            closeGrabber()
        else:
            openGrabber()

        pos = controllerState[1]
        orientation = controllerState[2]

        #rotate orientation by 90 degrees in the x axis
        orientation = pybullet.getEulerFromQuaternion(orientation)
        orientation = list(orientation)
        orientation[0] += math.pi
        orientation = pybullet.getQuaternionFromEuler(orientation)
        
        setEndEffectorPos(pos, orientation)

        #convert to tuple
        orientation = list(orientation)

        if controllerState[6][7]!=0:
            time.sleep(2)
            startNextRun()
            is_recording = 1
            print('Recording initiated...')
        
        if controllerState[6][1]!=0:
            stopRun()
            print('Recording stopped...')
            time.sleep(2) #stop mid-reset pictures from being recorded
            # robotId = reset()
            # time.sleep(5)

#start the controller thread
thread = threading.Thread(target=updateControllerContinuously)
thread.start()
# Out:
# Recording initiated...
# Warning: Data collection is too slow, took 0.16012954711914062 seconds to collect one image
# Warning: Data collection is too slow, took 0.2001488208770752 seconds to collect one image
# Warning: Data collection is too slow, took 0.17240118980407715 seconds to collect one image
# Warning: Data collection is too slow, took 0.14948797225952148 seconds to collect one image
# Warning: Data collection is too slow, took 0.13767194747924805 seconds to collect one image
# Warning: Data collection is too slow, took 0.14908218383789062 seconds to collect one image
# Warning: Data collection is too slow, took 0.17193222045898438 seconds to collect one image
# Warning: Data collection is too slow, took 0.16236090660095215 seconds to collect one image
# Warning: Data collection is too slow, took 0.16839289665222168 seconds to collect one image
# Warning: Data collection is too slow, took 0.16427969932556152 seconds to collect one image
# Warning: Data collection is too slow, took 0.1705765724182129 seconds to collect one image
# Warning: Data collection is too slow, took 0.16026759147644043 seconds to collect one image
# Warning: Data collection is too slow, took 0.12896180152893066 seconds to collect one image
# Warning: Data collection is too slow, took 0.13620805740356445 seconds to collect one image
# Warning: Data collection is too slow, took 0.10461139678955078 seconds to collect one image
seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow, took0.2596590518951416  seconds to collect one image0.24632525444030762
#  Warning: Data collection is too slow, took seconds to collect one image
# 0.21191906929016113 seconds to collect one image
# Warning: Data collection is too slow, took 0.18183374404907227 seconds to collect one image
# Warning: Data collection is too slow, took 0.13673663139343262 seconds to collect one image
# Warning: Data collection is too slow, took 0.4989640712738037 seconds to collect one image
# Warning: Data collection is too slow, took 0.2809028625488281 Warning: Data collection is too slow, took 0.18610811233520508 seconds to collect one image
# Warning: Data collection is too slow, took 0.1561720371246338 seconds to collect one imageseconds to collect one image
# Exception in thread Thread-59:
# Traceback (most recent call last):
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Ronak\AppData\Local\Temp/ipykernel_4956/2943470274.py", line 50, in continuousRecordImgs10Hz
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'data_all_cam_task_1406/52'
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.20762991905212402 seconds to collect one image
#  0.15579986572265625 seconds to collect one image
# Recording stopped...
# Recording stopped...
# Recording initiated...
# Warning: Data collection is too slow, took 0.14306974411010742 seconds to collect one image
# Warning: Data collection is too slow, took 0.1027231216430664 seconds to collect one image
# Warning: Data collection is too slow, took 0.11814522743225098 seconds to collect one image
# Warning: Data collection is too slow, took 0.10767960548400879 seconds to collect one image
# Warning: Data collection is too slow, took 0.11681175231933594 seconds to collect one image
# Warning: Data collection is too slow, took 0.11842632293701172 seconds to collect one image
# Warning: Data collection is too slow, took 0.1848008632659912 seconds to collect one image
# Warning: Data collection is too slow, took 0.16401267051696777 seconds to collect one image
# Warning: Data collection is too slow, took 0.16805410385131836 seconds to collect one image
# Warning: Data collection is too slow, took 0.16812539100646973 seconds to collect one image
# Warning: Data collection is too slow, took 0.16823172569274902 seconds to collect one image
# Warning: Data collection is too slow, took 0.15865707397460938 seconds to collect one image
# Warning: Data collection is too slow, took 0.13700103759765625 seconds to collect one image
# Warning: Data collection is too slow, took 0.14706063270568848 seconds to collect one image
# Warning: Data collection is too slow, took 0.12109756469726562 seconds to collect one image
# Recording initiated...Warning: Data collection is too slow, took
#  0.15886139869689941 Warning: Data collection is too slow, took 0.20362472534179688 seconds to collect one image
# seconds to collect one imageWarning: Data collection is too slow, took 0.17197299003601074 seconds to collect one image
#
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.359032869338989260.31450414657592773 seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.32118511199951170.3175973892211914  seconds to collect one imageseconds to collect one image
#
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.36083054542541504 seconds to collect one image
#  Warning: Data collection is too slow, took0.3259096145629883  0.15911102294921875 seconds to collect one image
# Warning: Data collection is too slow, tookseconds to collect one image
#  0.17194604873657227 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.16051220893859863 seconds to collect one image 0.2917041778564453
# seconds to collect one image
# Warning: Data collection is too slow, took 0.16067981719970703 seconds to collect one image
# Warning: Data collection is too slow, took 0.18024945259094238 seconds to collect one imageWarning: Data collection is too slow, took
#  0.5191800594329834 seconds to collect one image
# Warning: Data collection is too slow, took 0.29166316986083984Warning: Data collection is too slow, took seconds to collect one image
#  0.1573643684387207 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.3716752529144287  0.3616979122161865 seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, took 0.18274831771850586 seconds to collect one image
# Warning: Data collection is too slow, took 0.13205218315124512Warning: Data collection is too slow, took seconds to collect one image
#  0.423170804977417Warning: Data collection is too slow, took 0.13200950622558594 seconds to collect one image
#  seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.33594679832458496 seconds to collect one image 0.22611308097839355 seconds to collect one image
#
# Warning: Data collection is too slow, took 0.21794915199279785 seconds to collect one image
# Warning: Data collection is too slow, took 0.44519853591918945 seconds to collect one image
# Warning: Data collection is too slow, took 0.3655843734741211 seconds to collect one imageWarning: Data collection is too slow, took
#  0.2132277488708496 seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow,
seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, took 0.1593160629272461 Warning: Data collection is too slow, tookseconds to collect one image 0.2808654308319092
# seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.2500638961791992  seconds to collect one image
# Warning: Data collection is too slow, took 0.14442873001098633 seconds to collect one image
# 0.39122796058654785 seconds to collect one image
# Warning: Data collection is too slow, took 0.19991397857666016 seconds to collect one image
# Warning: Data collection is too slow, took 0.25588369369506836 seconds to collect one image
# Warning: Data collection is too slow, took 0.34417223930358887 seconds to collect one image
# Warning: Data collection is too slow, took 0.13390064239501953 Warning: Data collection is too slow, took seconds to collect one image0.16019630432128906
#  Warning: Data collection is too slow, took seconds to collect one image0.21770548820495605
#  seconds to collect one image
# Warning: Data collection is too slow, took 0.23568511009216309 seconds to collect one image
# Warning: Data collection is too slow, took 0.43999743461608887 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.3830451965332031 seconds to collect one image0.2272968292236328 seconds to collect one image
#
# Warning: Data collection is too slow, took 0.21622300148010254 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.30910134315490720.23588085174560547  seconds to collect one imageseconds to collect one image
# Warning: Data collection is too slow, took
# 0.21174120903015137 seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow, took 0.19875764846801758 seconds to collect one image
# 0.22876691818237305 seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow, took 0.26007413864135740.33299899101257324  seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.37584805488586426  0.3097493648529053 seconds to collect one imageseconds to collect one image
#
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.30698990821838380.4366471767425537  seconds to collect one image
# Warning: Data collection is too slow, took 0.19359350204467773 seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, took 0.17620038986206055 seconds to collect one image
# Warning: Data collection is too slow, took 0.29690051078796387 seconds to collect one image
# Warning: Data collection is too slow, took 0.39809346199035645 Warning: Data collection is too slow, tookseconds to collect one image
# 0.2438664436340332 seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow, took 0.17011737823486328 seconds to collect one image
# 0.18727684020996094 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.17687511444091797 seconds to collect one image
# Exception in thread Thread-70:
# Traceback (most recent call last):
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Ronak\AppData\Local\Temp/ipykernel_4956/2943470274.py", line 50, in continuousRecordImgs10Hz
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'data_all_cam_task_1406/64'
#  0.26831889152526855 seconds to collect one image
# Warning: Data collection is too slow, took 0.14181160926818848 seconds to collect one image
# Recording stopped...
# Recording initiated...Warning: Data collection is too slow, took 0.10016250610351562 seconds to collect one image
# Warning: Data collection is too slow, took
#  0.11987829208374023 seconds to collect one image
# Warning: Data collection is too slow, took 0.11128115653991699 seconds to collect one image
# Warning: Data collection is too slow, took 0.13027143478393555 seconds to collect one image
# Warning: Data collection is too slow, took 0.10300183296203613 seconds to collect one image
# Warning: Data collection is too slow, took 0.12209296226501465 seconds to collect one image
# Warning: Data collection is too slow, took 0.14696741104125977 seconds to collect one image
# Warning: Data collection is too slow, took 0.16289472579956055 seconds to collect one image
# Warning: Data collection is too slow, took 0.15012192726135254 seconds to collect one image
# Warning: Data collection is too slow, took 0.15998482704162598 seconds to collect one image
# Warning: Data collection is too slow, took 0.16918134689331055 seconds to collect one image
# Warning: Data collection is too slow, took 0.16413211822509766 seconds to collect one image
# Warning: Data collection is too slow, took 0.169647216796875 seconds to collect one image
# Warning: Data collection is too slow, took 0.1182408332824707 seconds to collect one image
# Warning: Data collection is too slow, took 0.13376450538635254 seconds to collect one image
# Warning: Data collection is too slow, took 0.1619873046875 seconds to collect one image
# Recording initiated...
# Warning: Data collection is too slow, took 0.32883214950561523 seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow, took 0.47714400291442870.18617916107177734  seconds to collect one imageseconds to collect one image
#
# Warning: Data collection is too slow, took 0.164109468460083 seconds to collect one image
# Warning: Data collection is too slow, took 0.17708826065063477 seconds to collect one image
# Warning: Data collection is too slow, took 0.27795958518981934 seconds to collect one image
# Warning: Data collection is too slow, took 0.3878662586212158 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.3612358570098877 seconds to collect one image
#  0.31439995765686035 seconds to collect one image
# Warning: Data collection is too slow, took 0.2929666042327881 seconds to collect one image
# Warning: Data collection is too slow, took 0.20096397399902344 seconds to collect one image
# Warning: Data collection is too slow, took 0.17311573028564453 seconds to collect one image
# Warning: Data collection is too slow, took 0.31807923316955566 Warning: Data collection is too slow, took 0.13683438301086426 seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, took 0.22446107864379883Warning: Data collection is too slow, took  seconds to collect one image0.217972993850708
#  seconds to collect one imageWarning: Data collection is too slow, took
#  0.1279609203338623 seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow, took 0.2007298469543457 seconds to collect one image
# 0.2146139144897461Warning: Data collection is too slow, took  0.1710805892944336 seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow, took0.2684938907623291  0.29729509353637695seconds to collect one image seconds to collect one image
#
# Warning: Data collection is too slow, took 0.18726873397827148 Warning: Data collection is too slow, tookseconds to collect one image 0.19062089920043945 seconds to collect one image
#
# Warning: Data collection is too slow, took 0.22921299934387207 seconds to collect one image
# Warning: Data collection is too slow, took 0.41104698181152344 Warning: Data collection is too slow, tookseconds to collect one image
#  0.2489180564880371 seconds to collect one imageWarning: Data collection is too slow, took
#  0.20873236656188965 seconds to collect one imageWarning: Data collection is too slow, took
#  0.16018295288085938 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.23923110961914062 seconds to collect one image
# 0.3439934253692627Warning: Data collection is too slow, took 0.170914888381958 seconds to collect one image
#  seconds to collect one image
# Warning: Data collection is too slow, took 0.17863678932189941 seconds to collect one image
# Warning: Data collection is too slow, took 0.2523772716522217 seconds to collect one image
# Warning: Data collection is too slow, took Warning: Data collection is too slow, took0.42286181449890137  seconds to collect one image
# 0.4029223918914795 Warning: Data collection is too slow, took 0.1660604476928711 seconds to collect one image
# seconds to collect one image
# Warning: Data collection is too slow, took 0.29009461402893066 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.6276960372924805 seconds to collect one image
#  0.20264244079589844Warning: Data collection is too slow, took 0.2251901626586914 seconds to collect one image
#  seconds to collect one image
# Warning: Data collection is too slow, took 0.3297598361968994 seconds to collect one image
# Warning: Data collection is too slow, took 0.39510321617126465 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took  0.3076634407043457 seconds to collect one image
# 0.2795898914337158 seconds to collect one imageWarning: Data collection is too slow, took 0.22605180740356445 seconds to collect one image
#
# Warning: Data collection is too slow, took 0.12800049781799316 seconds to collect one image
# Warning: Data collection is too slow, took 0.18559861183166504 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.394439697265625 seconds to collect one image
#  0.3270835876464844 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.2940659523010254 seconds to collect one image
#  0.23964786529541016 seconds to collect one image
# Warning: Data collection is too slow, tookWarning: Data collection is too slow, took 0.2843172550201416  0.3352320194244385 seconds to collect one imageseconds to collect one image
#
# Warning: Data collection is too slow, took
# Exception in thread Thread-73:
# Traceback (most recent call last):
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Ronak\AppData\Local\Temp/ipykernel_4956/2943470274.py", line 50, in continuousRecordImgs10Hz
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'data_all_cam_task_1406/66'
#  Warning: Data collection is too slow, took0.13044500350952148  seconds to collect one image
# 0.18303346633911133 seconds to collect one image
# Warning: Data collection is too slow, took 0.2396259307861328 seconds to collect one image
# Warning: Data collection is too slow, took 0.17399930953979492 seconds to collect one image
# Recording stopped...
# Recording stopped...

# %%
#kill the thread
isRunning = False
isCollectingImgs = False

reset()
# Out:
# Exception in thread Thread-57:
# Traceback (most recent call last):
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 980, in _bootstrap_inner
# 4
#     self.run()
#   File "c:\Users\Ronak\anaconda3\envs\torch\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Ronak\AppData\Local\Temp/ipykernel_4956/3166752380.py", line 42, in updateControllerContinuously
#   File "C:\Users\Ronak\AppData\Local\Temp/ipykernel_4956/3120337108.py", line 22, in setEndEffectorPos
# pybullet.error: Joint index out-of-range.

# %%
#close the simulation
pybullet.disconnect()

# %% [markdown]
# # pre-trained model.

# %%
# control the robot arm with a deep learning model
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
# Out:
# c:\Users\Ronak\anaconda3\envs\torch\lib\site-packages\torchvision\io\image.py:11: UserWarning: Failed to load image Python extension: Could not find module 'C:\Users\Ronak\anaconda3\envs\torch\Lib\site-packages\torchvision\image.pyd' (or one of its dependencies). Try using the full path with constructor syntax.
#   warn(f"Failed to load image Python extension: {e}")

# %%
from VRNet import VRNet
from VRNet import DataPreprocessor

# %%
#load the model
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = VRNet().to(device)
model.load_state_dict(torch.load("model_all_cam_task3_epoch_1500.pt", map_location=device))
model.eval()

#setup data preprocesser

# rgb mean:  tensor([0.5231, 0.5100, 0.4927])
# rgb std:  tensor([0.1867, 0.2083, 0.2512])
# depth mean:  tensor([0.8959])
# depth std:  tensor([0.0430])
# states mean:  tensor([ 0.0081, -0.0053,  0.0088,  0.0304,  0.0053,  0.0292,  0.5139],
#        device='cuda:0')
# states std:  tensor([0.0215, 0.0279, 0.0781, 0.3493, 0.0188, 0.1732, 0.4998],
#        device='cuda:0')


preprocessor = DataPreprocessor(rgb_mean=torch.tensor([0.5231, 0.5100, 0.4927]), rgb_std=torch.tensor([0.1867, 0.2083, 0.2512]), depth_mean=torch.tensor([0.8959]), depth_std=torch.tensor([0.0430]), \
                        state_mean=torch.tensor([ 0.0081, -0.0053,  0.0088,  0.0304,  0.0053,  0.0292,  0.5139]), state_std=torch.tensor([0.0215, 0.0279, 0.0781, 0.3493, 0.0188, 0.1732, 0.4998]))

# %%
def getCurrentEndEffectorPose():
    global robotId
    pos, orientation = pybullet.getLinkState(robotId, 8, computeForwardKinematics=False)[0:2]
    z_off = 0.04
    pos = [pos[0], pos[1], pos[2] + z_off]
    return pos, orientation

#in a separate thread, continuously update the robot arm with the model
modelControllingRobot = True
vels = []
def updateRobotNN():
    startTime = time.time()
    rgb_top, depth_top, rgb_eff, depth_eff,rgb_side, depth_side, endEffectorPoints, endState, isOpen = getTrainingData()

    rgb_top = torch.from_numpy(rgb_top).permute(2, 0, 1)
    depth_top = torch.from_numpy(depth_top)
    rgb_top = rgb_top.unsqueeze(0).to(device).float() / 255
    depth_top = depth_top.unsqueeze(0).unsqueeze(0).to(device).float()

    rgb_eff = torch.from_numpy(rgb_eff).permute(2, 0, 1)
    depth_eff = torch.from_numpy(depth_eff)
    rgb_eff = rgb_eff.unsqueeze(0).to(device).float() / 255
    depth_eff = depth_eff.unsqueeze(0).unsqueeze(0).to(device).float()

    rgb_side = torch.from_numpy(rgb_side).permute(2, 0, 1)
    depth_side = torch.from_numpy(depth_side)
    rgb_side = rgb_side.unsqueeze(0).to(device).float() / 255
    depth_side = depth_side.unsqueeze(0).unsqueeze(0).to(device).float()

    #show images with matplotlib
    # plt.imshow(rgb[0].permute(1, 2, 0).detach().cpu().numpy())
    # plt.show()
    # plt.imshow(depth[0].detach().cpu().numpy())
    # plt.show()

    rgb_top_norm = preprocessor.normalizeRgb(rgb_top.cpu()).to(device)
    depth_top_norm = preprocessor.normalizeDepth(depth_top.cpu()).to(device)

    rgb_eff_norm = preprocessor.normalizeRgb(rgb_eff.cpu()).to(device)
    depth_eff_norm = preprocessor.normalizeDepth(depth_eff.cpu()).to(device)

    rgb_side_norm = preprocessor.normalizeRgb(rgb_side.cpu()).to(device)
    depth_side_norm = preprocessor.normalizeDepth(depth_side.cpu()).to(device)
    
    
    y = model(rgb_top_norm, depth_top_norm, rgb_eff_norm, depth_eff_norm, rgb_side_norm, depth_side_norm)

    #convert the output to a list of velocities
    outputs = y.detach().cpu()
    outputs = preprocessor.denormalizeState(outputs)
    outputs = outputs[0].numpy()
    
    Vx, Vy, Vz, Wx, Wy, Wz, grabberOpen = outputs

    #compute the next position of the end effector in 100 ms
    pos, orn = getCurrentEndEffectorPose()
    x, y, z = pos
    
    x += Vx * 0.5 #use 0.5 instead of 0.1 to make the robot move faster for demos
    y += Vy * 0.5
    z += Vz * 0.5
    # roll += Wx * 0.01 #for simplicity, no angular control
    # pitch += Wy * 0.01
    # yaw += Wz * 0.01
    # vels.append([Vx, Vy, Vz, rgb[0].permute(1, 2, 0).detach().cpu().numpy()])

    pos = np.array([x, y, z])
    orn = pybullet.getQuaternionFromEuler([0, math.pi, -math.pi/1.7])

    #move the robot arm to the next position
    setEndEffectorPos(pos, orn)

    #open or close the grabber
    if grabberOpen > 0.5:
        openGrabber()
    else:
        closeGrabber()

    dt = time.time() - startTime
    if dt < 0.1:
        time.sleep(0.1 - dt)
    else:
        print("Warning: updateRobotNN took too long: ", dt)

def updateRobotContinuous():
    while modelControllingRobot:
        updateRobotNN()

#start the thread
thread = threading.Thread(target=updateRobotContinuous)
thread.start()
# Out:
# Warning: updateRobotNN took too long:  15.949866771697998
# Warning: updateRobotNN took too long:  0.5213742256164551
# Warning: updateRobotNN took too long:  0.49442195892333984
# Warning: updateRobotNN took too long:  0.48984456062316895
# Warning: updateRobotNN took too long:  0.49622583389282227
# Warning: updateRobotNN took too long:  0.4989473819732666
# Warning: updateRobotNN took too long:  0.5040397644042969
# Warning: updateRobotNN took too long:  0.9876983165740967
# Warning: updateRobotNN took too long:  1.490046739578247
# Warning: updateRobotNN took too long:  1.233457326889038
# Warning: updateRobotNN took too long:  1.1718180179595947
# Warning: updateRobotNN took too long:  1.0544745922088623
# Warning: updateRobotNN took too long:  0.9302206039428711
# Warning: updateRobotNN took too long:  3.3281757831573486
# Warning: updateRobotNN took too long:  0.19510650634765625
# Warning: updateRobotNN took too long:  0.19527983665466309
# Warning: updateRobotNN took too long:  0.19131851196289062
